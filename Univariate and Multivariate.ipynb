# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


df=pd.read_csv(r'C:\Users\logic\Documents\datascience\IT Salary Survey EU 2018.csv')
df.head(5)
df.isnull().sum()
# Out:
# Timestamp                               0
# Age                                    93
# Gender                                 14
# City                                   29
# Position                               28
# Years of experience                    33
# Your level                             22
# Current Salary                         15
# Salary one year ago                   169
# Salary two years ago                  302
# Are you getting any Stock Options?     23
# Main language at work                  15
# Company size                           15
# Company type                           35
# dtype: int64

# %% [markdown]
# # Univariate Analysis
# ## categorical data

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['Are you getting any Stock Options?'])
#it plots the number of people getting stocks  yes/no
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Are you getting any Stock Options?', ylabel='count'>

# %%
df['Are you getting any Stock Options?'].value_counts()
# Out:
# No     587
# Yes    155
# Name: Are you getting any Stock Options?, dtype: int64

# %%
plt.figure(figsize=(5,5))
df['Are you getting any Stock Options?'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(36,10))
df['Are you getting any Stock Options?'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Are you getting any Stock Options?'>

# %%
df['Are you getting any Stock Options?'].value_counts().plot(kind='pie',autopct='%.3f' )
# to show percentage of people getting stocks yes/no
# Out:
# <AxesSubplot:ylabel='Are you getting any Stock Options?'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# ## Histogram

# %%
plt.hist(df['Years of experience'])
# it shows the years of  experience of employes with the no. people in data
# Out:
# (array([ 88., 243., 242., 109.,  25.,  20.,   2.,   2.,   0.,   1.]),
#  array([ 0. ,  3.8,  7.6, 11.4, 15.2, 19. , 22.8, 26.6, 30.4, 34.2, 38. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['Age'])
#it shows probablity distribution and skewness
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df['Age'])
# we use to see noise int data (possible outliers)
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df['Age'].max()
# Out:
# 60.0

# %%
df['Age'].min()
# Out:
# 21.0

# %%
df['Age'].mean()
# Out:
# 32.183035714285715

# %%
df['Age'].max()
# Out:
# 60.0

# %% [markdown]
# # bivariate Analysis

# %% [markdown]
# # Scatterplot (Numerical- NUmerical)

# %%
sns.scatterplot(df['Age'],df['Current Salary'],hue=df['Years of experience'],style=df['Company size'],size=df['Years of experience'])
# displaying 5 different types of numerical variabe
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Current Salary'>

# %% [markdown]
# # Bar Plot(Numerical - Categorical)

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Years of experience'],df['Age'],hue=df['Gender'])
# it shows gender relationship with years of exp and age
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Years of experience', ylabel='Age'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(df['Years of experience'],df['Age'],hue=df['Gender'])
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Years of experience', ylabel='Age'>

# %% [markdown]
# # Boxplot (Numerical-Categorical)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df['Gender'],df['Age'])
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %% [markdown]
# # Distplot (Numerical-Categorical)

# %%
sns.distplot(df[df['Gender']=='F'] ['Salary two years ago'])
sns.distplot(df[df['Gender']=='M']['Salary two years ago'])
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary two years ago', ylabel='Density'>

# %%
pd.crosstab(df['Your level'],df['Gender'])
# Out:
# Gender       F    M
# Your level
# Junior      19   21
# Middle      51  154
# Senior      33  462

# %% [markdown]
# # Heat mAP(cATEGORICAL- cATEGORICAL)

# %%
sns.heatmap(pd.crosstab(df['Your level'],df['Gender']))
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Your level'>

# %% [markdown]
# #  Cluster mAP(cATEGORICAL- cATEGORICAL)

# %%
plt.figure(figsize=(36,10))
(df.groupby('Company type').mean()['Current Salary']*100).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Company type'>

# %% [markdown]
# #  PairPlot

# %%
sns.pairplot(df,hue='Your level')
# most important , to show dependdency of each variable with another

# %% [markdown]
# # Line Plot

# %%
new = df.groupby('Your level').mean()
new.head()
# Out:
#                   Age  Years of experience  Current Salary  \
# Your level
# Junior      28.666667             1.842105    48078.384615
# Middle      30.398936             5.860697    57844.634146
# Senior      33.124153            10.127835    74072.670020
#
#             Salary one year ago  Salary two years ago
# Your level
# Junior             41831.347826          35193.875000
# Middle             51387.133758          46860.834862
# Senior             67187.114634          62463.381381

# %%
sns.lineplot(new['Years of experience'],new['Current Salary'])
# ususally used for time series  wrt.  x and y data
# Out:
# C:\Users\logic\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Years of experience', ylabel='Current Salary'>

# %%
df.pivot_table(values='Current Salary',index='Company type',columns='Your level')
# to display the data by  dividing the index into subcategories  with counts
# Out:
# Your level                                       Junior        Middle  \
# Company type
# Agency                                     46666.666667  55153.571429
# Automotive                                          NaN           NaN
# Bank                                                NaN           NaN
# Big Tech                                            NaN           NaN
# Blockchain technology                               NaN           NaN
# Consult                                             NaN  42000.000000
# Consultancy                                49000.000000           NaN
# Consulting                                          NaN  54500.000000
# Consulting (banking)                       50000.000000           NaN
# Consulting Company                                  NaN  62000.000000
# Corporation                                         NaN  75800.000000
# Development                                         NaN           NaN
# E-Commerce                                          NaN  63000.000000
# E-Commerce firm                                     NaN  46000.000000
# Ecom retailer                                       NaN           NaN
# Ecommerce                                           NaN           NaN
# Fin Tech                                            NaN           NaN
# GmbH                                                NaN           NaN
# Hochschule/university                               NaN  37000.000000
# ISP                                                 NaN  33600.000000
# IT Consultancy                                      NaN  65000.000000
# IT Consultants                                      NaN           NaN
# IT Consulting                                       NaN           NaN
# IT Consulting                                       NaN           NaN
# IT Dienstleistungen                                 NaN           NaN
# IT Service Provider                                 NaN           NaN
# IT-Beratung                                         NaN           NaN
# Industry                                   60000.000000           NaN
# Insurance                                           NaN           NaN
# Internal development for a non-IT company           NaN           NaN
# Manufacturing                              60000.000000           NaN
# OEM                                                 NaN           NaN
# Outsorce                                            NaN           NaN
# Outsource                                           NaN  62000.000000
# Outsourcing                                         NaN           NaN
# Personaldienstleister                               NaN           NaN
# Product                                    48232.280000  59506.504065
# Product and Projects                                NaN  52000.000000
# Project-based software development                  NaN  75000.000000
# Retail                                              NaN  60000.000000
# Startup                                    44450.000000  55090.000000
# Stock market                                        NaN  65000.000000
# Technology Consulting                      46000.000000           NaN
# consulting                                          NaN           NaN
# e-commerce                                          NaN           NaN
# ipo                                                 NaN           NaN
# non-IT, manufacturing                               NaN           NaN
# outsource                                           NaN           NaN
# telecom operator                                    NaN           NaN
#
# Your level                                        Senior
# Company type
# Agency                                      74653.690476
# Automotive                                 103500.000000
# Bank                                        90000.000000
# Big Tech                                   132250.000000
# Blockchain technology                       83000.000000
# Consult                                              NaN
# Consultancy                                 95000.000000
# Consulting                                  68666.666667
# Consulting (banking)                                 NaN
# Consulting Company                                   NaN
# Corporation                                 80000.000000
# Development                                115000.000000
# E-Commerce                                           NaN
# E-Commerce firm                                      NaN
# Ecom retailer                               69000.000000
# Ecommerce                                  100000.000000
# Fin Tech                                    90000.000000
# GmbH                                       100000.000000
# Hochschule/university                                NaN
# ISP                                                  NaN
# IT Consultancy                                       NaN
# IT Consultants                              48000.000000
# IT Consulting                               65000.000000
# IT Consulting                               92000.000000
# IT Dienstleistungen                         68000.000000
# IT Service Provider                         72000.000000
# IT-Beratung                                 64500.000000
# Industry                                             NaN
# Insurance                                   93000.000000
# Internal development for a non-IT company   75000.000000
# Manufacturing                                        NaN
# OEM                                         80400.000000
# Outsorce                                    38000.000000
# Outsource                                   51400.000000
# Outsourcing                                 66333.333333
# Personaldienstleister                       60000.000000
# Product                                     74174.786441
# Product and Projects                                 NaN
# Project-based software development                   NaN
# Retail                                               NaN
# Startup                                     69671.844660
# Stock market                                         NaN
# Technology Consulting                                NaN
# consulting                                  48000.000000
# e-commerce                                  76000.000000
# ipo                                         70000.000000
# non-IT, manufacturing                       66000.000000
# outsource                                   39150.000000
# telecom operator                            60000.000000
